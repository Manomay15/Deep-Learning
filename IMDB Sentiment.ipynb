# %%
import tensorflow as tf

# %%
import tensorflow_datasets as tfds
datasets, info = tfds.load("imdb_reviews", as_supervised=True, with_info=True)
train_size = info.splits["train"].num_examples
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to ~\tensorflow_datasets\imdb_reviews\plain_text\1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling ~\tensorflow_datasets\imdb_reviews\plain_text\1.0.0.incompleteHOZBQ2\imdb_reviews-train.tfrecord*...…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling ~\tensorflow_datasets\imdb_reviews\plain_text\1.0.0.incompleteHOZBQ2\imdb_reviews-test.tfrecord*...:…
# Generating unsupervised examples...: 0 examples [00:00, ? examples/s]
# Shuffling ~\tensorflow_datasets\imdb_reviews\plain_text\1.0.0.incompleteHOZBQ2\imdb_reviews-unsupervised.tfrec…
# Dataset imdb_reviews downloaded and prepared to ~\tensorflow_datasets\imdb_reviews\plain_text\1.0.0. Subsequent calls will reuse this data.

# %%
def preprocess(X_batch, y_batch):
 X_batch = tf.strings.substr(X_batch, 0, 300)
 X_batch = tf.strings.regex_replace(X_batch, b"<br\\s*/?>", b" ")
 X_batch = tf.strings.regex_replace(X_batch, b"[^a-zA-Z']", b" ")
 X_batch = tf.strings.split(X_batch)
 return X_batch.to_tensor(default_value=b"<pad>"), y_batch

# %%
from collections import Counter
vocabulary = Counter()
for X_batch, y_batch in datasets["train"].batch(32).map(preprocess):
 for review in X_batch:
     vocabulary.update(list(review.numpy()))

# %%
vocabulary.most_common()
# Out:
# [(b'<pad>', 214309),
#  (b'the', 61137),
#  (b'a', 38564),
#  (b'of', 33983),
#  (b'and', 33431),
#  (b'to', 27707),
#  (b'I', 27019),
#  (b'is', 25719),
#  (b'in', 18966),
#  (b'this', 18490),
#  (b'it', 17690),
#  (b'was', 14950),
#  (b'movie', 14945),
#  (b'that', 14752),
#  (b'The', 11879),
#  (b'film', 10668),
#  (b'with', 9073),
#  (b'for', 8660),
#  (b'as', 8578),
#  (b'on', 7817),
#  (b'but', 7724),
#  (b'have', 7031),
#  (b'This', 6672),
#  (b'one', 6475),
#  (b'not', 6325),
#  (b'be', 5888),
#  (b'are', 5665),
#  (b'you', 5500),
#  (b'an', 5183),
#  (b'at', 4814),
#  (b'about', 4799),
#  (b'by', 4717),
#  (b'all', 4655),
#  (b'his', 4625),
#  (b'so', 4521),
#  (b'like', 4428),
#  (b'from', 4321),
#  (b'who', 4266),
#  (b'has', 4178),
#  (b'It', 4038),
#  (b'good', 3727),
#  (b'my', 3662),
#  (b'just', 3636),
#  (b'very', 3571),
#  (b'out', 3376),
#  (b'or', 3302),
#  (b'story', 3211),
#  (b'some', 3197),
#  (b'time', 3126),
#  (b'had', 3121),
#  (b'he', 3096),
#  (b'they', 3008),
#  (b'really', 2924),
#  (b'me', 2923),
#  (b'when', 2812),
#  (b'what', 2805),
#  (b'first', 2791),
#  (b'movies', 2754),
#  (b'bad', 2650),
#  (b'see', 2620),
#  (b'seen', 2562),
#  (b'up', 2508),
#  (b'only', 2507),
#  (b'were', 2481),
#  (b"it's", 2476),
#  (b'would', 2451),
#  (b'more', 2436),
#  (b'made', 2422),
#  (b'great', 2407),
#  (b'can', 2337),
#  (b'been', 2336),
#  (b'i', 2330),
#  (b'her', 2322),
#  (b'no', 2305),
#  (b'A', 2257),
#  (b'which', 2178),
#  (b'even', 2158),
#  (b'films', 2121),
#  (b'there', 2107),
#  (b'ever', 2105),
#  (b'people', 2086),
#  (b'much', 2080),
#  (b'because', 2072),
#  (b'most', 2038),
#  (b'plot', 1979),
#  (b'if', 1978),
#  (b'than', 1938),
#  (b'acting', 1904),
#  (b'get', 1827),
#  (b'their', 1817),
#  (b'well', 1803),
#  (b'into', 1794),
#  (b'how', 1791),
#  (b'best', 1756),
#  (b'think', 1746),
#  (b'other', 1709),
#  (b'its', 1701),
#  (b"It's", 1699),
#  (b'saw', 1676),
#  (b'could', 1658),
#  (b'watch', 1651),
#  (b'many', 1630),
#  (b"don't", 1610),
#  (b'do', 1593),
#  (b'will', 1573),
#  (b'say', 1569),
#  (b'show', 1561),
#  (b'love', 1539),
#  (b'make', 1523),
#  (b'two', 1522),
#  (b'way', 1517),
#  (b'know', 1487),
#  (b'years', 1484),
#  (b'after', 1479),
#  (b'But', 1478),
#  (b'we', 1451),
#  (b'watching', 1437),
#  (b'In', 1423),
#  (b'never', 1416),
#  (b'any', 1403),
#  (b'life', 1402),
#  (b'characters', 1371),
#  (b"I'm", 1364),
#  (b'too', 1352),
#  (b'did', 1349),
#  (b"I've", 1337),
#  (b'little', 1337),
#  (b'over', 1295),
#  (b'If', 1282),
#  (b'she', 1277),
#  (b'then', 1274),
#  (b'being', 1269),
#  (b'thought', 1269),
#  (b'them', 1258),
#  (b'off', 1249),
#  (b'There', 1230),
#  (b's', 1219),
#  (b'funny', 1213),
#  (b'better', 1169),
#  (b'also', 1157),
#  (b'watched', 1124),
#  (b'where', 1117),
#  (b'still', 1112),
#  (b'worst', 1101),
#  (b'old', 1096),
#  (b'am', 1094),
#  (b'through', 1089),
#  (b'actors', 1087),
#  (b'And', 1063),
#  (b'character', 1061),
#  (b'such', 1060),
#  (b"didn't", 1056),
#  (b'back', 1055),
#  (b'got', 1055),
#  (b'horror', 1041),
#  (b'those', 1035),
#  (b'series', 1033),
#  (b'lot', 1025),
#  (b'should', 1022),
#  (b'comedy', 993),
#  (b'go', 991),
#  (b'your', 991),
#  (b'few', 981),
#  (b'something', 979),
#  (b'does', 962),
#  (b'thing', 956),
#  (b'him', 952),
#  (b'man', 950),
#  (b'What', 939),
#  (b'going', 938),
#  (b'original', 933),
#  (b'director', 931),
#  (b'work', 927),
#  (b'here', 919),
#  (b'before', 904),
#  (b'real', 901),
#  (b'actually', 898),
#  (b'cast', 894),
#  (b'pretty', 884),
#  (b'TV', 880),
#  (b'quite', 870),
#  (b'why', 870),
#  (b'every', 867),
#  (b'He', 853),
#  (b'find', 851),
#  (b'As', 850),
#  (b'scenes', 847),
#  (b'young', 846),
#  (b"can't", 843),
#  (b'interesting', 832),
#  (b'same', 829),
#  (b'fan', 818),
#  (b'now', 815),
#  (b'makes', 813),
#  (b'end', 812),
#  (b'big', 804),
#  (b'When', 804),
#  (b'long', 802),
#  (b'nothing', 796),
#  (b'times', 792),
#  (b'found', 791),
#  (b"'s", 790),
#  (b'must', 786),
#  (b'these', 775),
#  (b'again', 772),
#  (b'another', 768),
#  (b'part', 766),
#  (b'action', 762),
#  (b'though', 757),
#  (b'always', 753),
#  (b'script', 753),
#  (b"doesn't", 750),
#  (b'last', 744),
#  (b'new', 742),
#  (b'fact', 736),
#  (b'year', 733),
#  (b'while', 733),
#  (b'around', 730),
#  (b'look', 729),
#  (b'since', 728),
#  (b't', 716),
#  (b'minutes', 712),
#  (b'family', 699),
#  (b'DVD', 697),
#  (b'down', 684),
#  (b'scene', 683),
#  (b'things', 682),
#  (b'want', 676),
#  (b'read', 674),
#  (b'seems', 668),
#  (b'My', 668),
#  (b'fun', 651),
#  (b'may', 651),
#  (b'world', 649),
#  (b'done', 649),
#  (b'far', 648),
#  (b'come', 645),
#  (b'right', 645),
#  (b'take', 645),
#  (b"wasn't", 638),
#  (b'You', 635),
#  (b'th', 634),
#  (b'believe', 633),
#  (b'almost', 632),
#  (b'enough', 631),
#  (b'hard', 630),
#  (b'whole', 621),
#  (b'anything', 621),
#  (b'book', 620),
#  (b"isn't", 617),
#  (b'probably', 616),
#  (b'least', 613),
#  (b'give', 612),
#  (b'bit', 612),
#  (b'They', 610),
#  (b'American', 605),
#  (b'seeing', 604),
#  (b'without', 603),
#  (b'feel', 600),
#  (b'One', 598),
#  (b'awful', 597),
#  (b'idea', 592),
#  (b'making', 590),
#  (b'between', 590),
#  (b'remember', 588),
#  (b'came', 587),
#  (b'music', 587),
#  (b'kind', 586),
#  (b'set', 584),
#  (b'excellent', 581),
#  (b'John', 581),
#  (b'classic', 580),
#  (b'us', 575),
#  (b'both', 575),
#  (b'Well', 573),
#  (b'version', 571),
#  (b'performance', 568),
#  (b'gets', 567),
#  (b'plays', 560),
#  (b'day', 552),
#  (b'Not', 550),
#  (b'low', 550),
#  (b'might', 550),
#  (b'own', 547),
#  (b'loved', 547),
#  (b'budget', 545),
#  (b'role', 544),
#  (b'reason', 543),
#  (b'high', 543),
#  (b'First', 541),
#  (b'girl', 540),
#  (b'shows', 535),
#  (b'looking', 533),
#  (b'After', 533),
#  (b'For', 532),
#  (b'So', 528),
#  (b'video', 526),
#  (b'special', 525),
#  (b'However', 523),
#  (b'effects', 523),
#  (b'woman', 522),
#  (b'different', 521),
#  (b'terrible', 519),
#  (b'true', 519),
#  (b'point', 516),
#  (b'start', 515),
#  (b'actor', 512),
#  (b'put', 510),
#  (b'night', 506),
#  (b'three', 505),
#  (b'played', 504),
#  (b'liked', 503),
#  (b'yet', 502),
#  (b'boring', 501),
#  (b'beautiful', 499),
#  (b'takes', 496),
#  (b'especially', 496),
#  (b'based', 493),
#  (b'ago', 492),
#  (b'main', 491),
#  (b'short', 489),
#  (b'play', 489),
#  (b'guy', 486),
#  (b'title', 486),
#  (b'said', 485),
#  (b'enjoyed', 483),
#  (b'anyone', 483),
#  (b'wonderful', 482),
#  (b'trying', 480),
#  (b"that's", 479),
#  (b'sure', 479),
#  (b'went', 477),
#  (b'favorite', 473),
#  (b'having', 472),
#  (b'stars', 469),
#  (b'together', 464),
#  (b'Hollywood', 463),
#  (b'absolutely', 460),
#  (b'screen', 460),
#  (b'our', 458),
#  (b'wrong', 458),
#  (b'rather', 456),
#  (b'half', 454),
#  (b'production', 454),
#  (b'episode', 452),
#  (b'goes', 448),
#  (b'place', 446),
#  (b'comes', 445),
#  (b'early', 443),
#  (b'piece', 442),
#  (b'written', 436),
#  (b'We', 435),
#  (b'heard', 435),
#  (b'away', 433),
#  (b"couldn't", 429),
#  (b'second', 429),
#  (b'money', 428),
#  (b'during', 426),
#  (b'friends', 426),
#  (b'job', 424),
#  (b'THE', 421),
#  (b'someone', 419),
#  (b'entertaining', 418),
#  (b'sense', 418),
#  (b'looks', 418),
#  (b'She', 417),
#  (b'line', 416),
#  (b'school', 416),
#  (b'drama', 415),
#  (b'each', 414),
#  (b'flick', 414),
#  (b'everything', 413),
#  (b'understand', 413),
#  (b'No', 410),
#  (b'mean', 405),
#  (b'course', 405),
#  (b'enjoy', 405),
#  (b'star', 403),
#  (b'wanted', 403),
#  (b'wife', 402),
#  (b'directed', 401),
#  (b'That', 401),
#  (b'To', 401),
#  (b'small', 400),
#  (b'mind', 399),
#  (b'seem', 397),
#  (b'truly', 397),
#  (b'While', 396),
#  (b'stupid', 395),
#  (b'simply', 394),
#  (b"'", 393),
#  (b'poor', 393),
#  (b'All', 391),
#  (b'worth', 391),
#  (b'everyone', 391),
#  (b'once', 386),
#  (b'worse', 385),
#  (b'top', 383),
#  (b'completely', 382),
#  (b'used', 382),
#  (b'cinema', 381),
#  (b'felt', 380),
#  (b'kids', 378),
#  (b'genre', 378),
#  (b'shot', 378),
#  (b'home', 376),
#  (b'name', 375),
#  (b'late', 375),
#  (b'tell', 374),
#  (b'called', 373),
#  (b'until', 372),
#  (b'reviews', 372),
#  (b'New', 369),
#  (b'myself', 369),
#  (b'beginning', 368),
#  (b'full', 367),
#  (b'nice', 367),
#  (b'live', 365),
#  (b'left', 364),
#  (b'At', 363),
#  (b'horrible', 360),
#  (b'novel', 359),
#  (b'How', 359),
#  (b'Although', 357),
#  (b'thriller', 356),
#  (b'documentary', 356),
#  (b'women', 355),
#  (b'starts', 354),
#  (b'performances', 353),
#  (b'several', 353),
#  (b'else', 349),
#  (b'Even', 348),
#  (b'audience', 348),
#  (b'less', 348),
#  (b'perfect', 345),
#  (b'often', 344),
#  (b'couple', 343),
#  (b'writing', 343),
#  (b'amazing', 343),
#  (b"I'd", 343),
#  (b'review', 341),
#  (b'released', 341),
#  (b'seemed', 340),
#  (b'history', 339),
#  (b'need', 339),
#  (b'case', 337),
#  (b'Some', 337),
#  (b'started', 335),
#  (b'later', 334),
#  (b'war', 334),
#  (b'waste', 333),
#  (b'Michael', 332),
#  (b'try', 330),
#  (b'use', 330),
#  (b'either', 329),
#  (b'given', 329),
#  (b'humor', 329),
#  (b'comments', 329),
#  (b'B', 327),
#  (b'black', 326),
#  (b'disappointed', 325),
#  (b'although', 325),
#  (b'laugh', 324),
#  (b'father', 324),
#  (b'along', 323),
#  (b'gave', 323),
#  (b'however', 323),
#  (b'quality', 323),
#  (b'b', 322),
#  (b'expect', 320),
#  (b'totally', 320),
#  (b'friend', 319),
#  (b'gives', 317),
#  (b'OK', 316),
#  (b'itself', 315),
#  (b'sex', 313),
#  (b'thinking', 312),
#  (b'surprised', 312),
#  (b"you're", 312),
#  (b'brilliant', 311),
#  (b'With', 311),
#  (b'Now', 311),
#  (b'others', 310),
#  (b'definitely', 310),
#  (b'entire', 309),
#  (b'dialogue', 308),
#  (b'days', 308),
#  (b'ending', 307),
#  (b"he's", 307),
#  (b'television', 306),
#  (b'already', 306),
#  (b'getting', 305),
#  (b'past', 305),
#  (b'let', 304),
#  (b'James', 303),
#  (b'boy', 302),
#  (b'camera', 301),
#  (b'style', 301),
#  (b'problem', 299),
#  (b'certainly', 299),
#  (b'Just', 297),
#  (b'group', 297),
#  (b'stories', 296),
#  (b'lead', 295),
#  (b'o', 295),
#  (b'town', 294),
#  (b'Why', 293),
#  (b'Of', 293),
#  (b'maybe', 293),
#  (b'person', 292),
#  (b'himself', 292),
#  (b'playing', 291),
#  (b'lost', 290),
#  (b'art', 290),
#  (b'supposed', 290),
#  (b'become', 289),
#  (b'doing', 289),
#  (b'usually', 285),
#  (b'lives', 285),
#  (b'men', 284),
#  (b'looked', 284),
#  (b'moments', 284),
#  (b'death', 284),
#  (b'hit', 283),
#  (b'kid', 283),
#  (b'took', 282),
#  (b'slow', 282),
#  (b'house', 282),
#  (b'known', 281),
#  (b'sort', 281),
#  (b'fine', 281),
#  (b'example', 280),
#  (b'recently', 280),
#  (b'picture', 279),
#  (b'premise', 278),
#  (b'An', 278),
#  (b'His', 278),
#  (b'crap', 277),
#  (b'knew', 277),
#  (b'British', 277),
#  (b'direction', 276),
#  (b'Robert', 275),
#  (b'child', 274),
#  (b'decided', 273),
#  (b'hour', 273),
#  (b'parts', 273),
#  (b'Mr', 272),
#  (b'help', 271),
#  (b'huge', 271),
#  (b'expecting', 271),
#  (b'From', 270),
#  (b'guess', 270),
#  (b'fans', 270),
#  (b'lines', 269),
#  (b'Man', 269),
#  (b'works', 269),
#  (b'son', 265),
#  (b'human', 265),
#  (b'attempt', 265),
#  (b'David', 264),
#  (b'children', 264),
#  (b'decent', 264),
#  (b'comment', 261),
#  (b'extremely', 261),
#  (b'finally', 261),
#  (b'sequel', 260),
#  (b'jokes', 260),
#  (b'keep', 260),
#  (b'admit', 258),
#  (b'actress', 258),
#  (b'etc', 257),
#  (b'writer', 256),
#  (b"there's", 255),
#  (b'episodes', 255),
#  (b'against', 254),
#  (b'type', 254),
#  (b'game', 254),
#  (b'simple', 253),
#  (b'musical', 253),
#  (b'heart', 252),
#  (b'George', 251),
#  (b'turned', 251),
#  (b'Yes', 251),
#  (b'tale', 250),
#  (b'storyline', 248),
#  (b'under', 248),
#  (b'greatest', 247),
#  (b'age', 247),
#  (b'romantic', 246),
#  (b'run', 246),
#  (b'opinion', 246),
#  (b'rest', 245),
#  (b'hilarious', 245),
#  (b'Richard', 245),
#  (b'able', 244),
#  (b'perhaps', 243),
#  (b'expected', 243),
#  (b'w', 243),
#  (b'saying', 241),
#  (b'close', 241),
#  (b'theater', 241),
#  (b'act', 240),
#  (b'opening', 240),
#  (b'involved', 240),
#  (b'killer', 239),
#  (b'told', 238),
#  (b'typical', 238),
#  (b"I'll", 237),
#  (b'guys', 237),
#  (b'Film', 236),
#  (b'throughout', 235),
#  (b'scary', 235),
#  (b'face', 235),
#  (b're', 234),
#  (b'head', 234),
#  (b'turn', 234),
#  (b'usual', 234),
#  (b'cannot', 234),
#  (b'mother', 233),
#  (b'serious', 233),
#  (b'hours', 232),
#  (b'York', 232),
#  (b'Its', 232),
#  (b'ridiculous', 231),
#  (b'bunch', 231),
#  (b'feeling', 230),
#  (b'next', 230),
#  (b'dark', 230),
#  (b"Don't", 229),
#  (b'wants', 229),
#  (b'care', 229),
#  (b'Unfortunately', 228),
#  (b'On', 228),
#  (b'predictable', 228),
#  (b'word', 228),
#  (b'side', 228),
#  (b'chance', 228),
#  (b'tries', 228),
#  (b'car', 227),
#  (b'Then', 227),
#  (b'fi', 226),
#  (b'today', 226),
#  (b'Disney', 225),
#  (b"There's", 225),
#  (b'remake', 225),
#  (b'self', 225),
#  (b'rented', 224),
#  (b'sometimes', 224),
#  (b'Peter', 223),
#  (b'br', 223),
#  (b'class', 223),
#  (b'dead', 223),
#  (b'strange', 222),
#  (b'local', 222),
#  (b'across', 221),
#  (b'acted', 220),
#  (b'girls', 219),
#  (b'cool', 218),
#  (b'animation', 218),
#  (b'middle', 218),
#  (b'happened', 217),
#  (b'silly', 217),
#  (b'rating', 217),
#  (b'stop', 216),
#  (b'instead', 216),
#  (b'modern', 216),
#  (b"haven't", 216),
#  (b'interest', 216),
#  (b'sound', 216),
#  (b'murder', 216),
#  (b'doubt', 216),
#  (b'matter', 215),
#  (b'complete', 215),
#  (b'exactly', 214),
#  (b'fantastic', 214),
#  (b'experience', 214),
#  (b"won't", 214),
#  (b'release', 214),
#  (b'talent', 214),
#  (b'stuff', 213),
#  (b'living', 213),
#  (b'white', 213),
#  (b'IMDb', 213),
#  (b'single', 213),
#  (b'obviously', 212),
#  (b'Tom', 212),
#  (b'upon', 212),
#  (b'enjoyable', 211),
#  (b'four', 211),
#  (b'five', 211),
#  (b'except', 210),
#  (b'S', 210),
#  (b'tried', 210),
#  (b'bought', 210),
#  (b'reading', 209),
#  (b'highly', 209),
#  (b'm', 208),
#  (b'coming', 208),
#  (b'due', 207),
#  (b'behind', 207),
#  (b'call', 207),
#  (b'Most', 207),
#  (b'e', 206),
#  (b'brother', 206),
#  (b'eyes', 205),
#  (b'French', 205),
#  (b'wonder', 204),
#  (b'War', 203),
#  (b'number', 203),
#  (b'shown', 202),
#  (b'sad', 202),
#  (b'tells', 202),
#  (b'famous', 201),
#  (b'feature', 201),
#  (b'filmed', 201),
#  (b'strong', 201),
#  (b'becomes', 200),
#  (b'somewhat', 200),
#  (b'box', 199),
#  (b'Oh', 199),
#  (b'hope', 199),
#  (b'wrote', 198),
#  (b'season', 198),
#  (b'obvious', 198),
#  (b'happen', 197),
#  (b'adaptation', 197),
#  (b'clich', 197),
#  (b'Paul', 196),
#  (b'lame', 196),
#  (b'Like', 196),
#  (b'viewing', 196),
#  (b'poorly', 196),
#  (b'moving', 195),
#  (b'career', 195),
#  (b'evil', 193),
#  (b'recommend', 193),
#  (b'King', 192),
#  (b'husband', 192),
#  (b'Oscar', 192),
#  (b'named', 191),
#  (b'viewer', 191),
#  (b'begin', 191),
#  (b'violence', 191),
#  (b'write', 191),
#  (b'non', 190),
#  (b'ones', 190),
#  (b'view', 190),
#  (b'expectations', 190),
#  (b'among', 189),
#  (b'dull', 189),
#  (b'wish', 189),
#  (b'masterpiece', 189),
#  (b'major', 189),
#  (b'straight', 188),
#  (b'agree', 188),
#  (b'Movie', 188),
#  (b'sit', 187),
#  (b'hand', 187),
#  (b'period', 187),
#  (b'directing', 186),
#  (b'particularly', 186),
#  (b'country', 186),
#  (b'fight', 186),
#  (b'hate', 186),
#  (b'daughter', 185),
#  (b'happens', 185),
#  (b'English', 185),
#  (b'says', 185),
#  (b'stand', 185),
#  (b'turns', 185),
#  (b'Christmas', 184),
#  (b'f', 184),
#  (b'attention', 184),
#  (b"That's", 184),
#  (b'taken', 184),
#  (b'cheesy', 184),
#  (b'comic', 183),
#  (b'mostly', 182),
#  (b"wouldn't", 182),
#  (b'light', 182),
#  (b'entertainment', 182),
#  (b'order', 182),
#  (b'roles', 182),
#  (b'superb', 181),
#  (b'dialog', 181),
#  (b'easily', 181),
#  (b'starring', 181),
#  (b'Lee', 181),
#  (b'weak', 180),
#  (b'mystery', 180),
#  (b'Night', 180),
#  (b'seriously', 180),
#  (b'realistic', 180),
#  (b'reasons', 180),
#  (b'theme', 179),
#  (b'possibly', 179),
#  (b'words', 179),
#  (b'ten', 179),
#  (b'cheap', 179),
#  (b'similar', 178),
#  (b'brought', 178),
#  (b'co', 178),
#  (b'including', 177),
#  (b'nearly', 177),
#  (b'cinematography', 177),
#  (b'falls', 176),
#  (b'basically', 176),
#  (b'produced', 176),
#  (b'talking', 176),
#  (b'working', 175),
#  (b'taking', 175),
#  (b'reality', 175),
#  (b'store', 175),
#  (b'unique', 175),
#  (b'forward', 174),
#  (b'hell', 173),
#  (b'alone', 173),
#  (b'T', 173),
#  (b'whose', 172),
#  (b'sets', 172),
#  (b'previous', 172),
#  (b'soon', 172),
#  (b'themselves', 171),
#  (b'lack', 171),
#  (b'killed', 170),
#  (b'directors', 170),
#  (b'c', 169),
#  (b'bring', 169),
#  (b'week', 169),
#  (b'effort', 169),
#  (b'average', 169),
#  (b'ways', 169),
#  (b'female', 168),
#  (b'running', 168),
#  (b'fast', 168),
#  (b'editing', 168),
#  (b'kept', 168),
#  (b'caught', 168),
#  (b'Japanese', 168),
#  (b'popular', 167),
#  (b'screenplay', 167),
#  (b'elements', 167),
#  (b'comedies', 167),
#  (b'surprise', 167),
#  (b'became', 166),
#  (b'problems', 166),
#  (b'Jack', 166),
#  (b'features', 166),
#  (b'annoying', 166),
#  (b'animated', 166),
#  (b'yes', 165),
#  (b'd', 165),
#  (b'possible', 165),
#  (b'cover', 165),
#  (b'follow', 165),
#  (b'near', 165),
#  (b'William', 165),
#  (b'list', 164),
#  (b'songs', 164),
#  (b'cartoon', 163),
#  (b'Having', 163),
#  (b'voice', 163),
#  (b'parents', 162),
#  (b'Maybe', 162),
#  (b'Star', 162),
#  (b'events', 162),
#  (b'none', 162),
#  (b'body', 162),
#  (b'crime', 161),
#  (b'h', 161),
#  (b'Great', 161),
#  (b'Who', 161),
#  (b'future', 161),
#  (b'Very', 161),
#  (b'weird', 160),
#  (b'God', 160),
#  (b"aren't", 160),
#  (b'actual', 160),
#  (b'despite', 159),
#  (b'final', 159),
#  (b'Is', 158),
#  (b'gore', 158),
#  (b'imagine', 157),
#  (b'change', 155),
#  (b'sister', 155),
#  (b'cut', 155),
#  (b"you'll", 155),
#  (b'D', 155),
#  (b'lots', 154),
#  (b'beyond', 154),
#  (b'moment', 154),
#  (b'Dr', 154),
#  (b'positive', 154),
#  (b'level', 153),
#  (b'fantasy', 153),
#  (b'important', 153),
#  (b'minute', 153),
#  (b'sci', 152),
#  (b'Joe', 152),
#  (b'easy', 152),
#  (b'era', 152),
#  (b'House', 152),
#  (b'awesome', 152),
#  (b'romance', 152),
#  (b'above', 152),
#  (b'team', 152),
#  (b'subject', 152),
#  (b'rent', 151),
#  (b'badly', 151),
#  (b'happy', 151),
#  (b'finds', 151),
#  (b'points', 151),
#  (b'rate', 151),
#  (b"'The", 150),
#  (b'begins', 150),
#  (b'message', 150),
#  (b'incredibly', 150),
#  (b'concept', 150),
#  (b'Italian', 150),
#  (b'realize', 149),
#  (b'Good', 149),
#  (b'recent', 149),
#  (b'score', 149),
#  (b'By', 148),
#  (b'casting', 148),
#  (b'America', 148),
#  (b'police', 148),
#  (b'SPOILERS', 148),
#  (b'power', 148),
#  (b"you've", 148),
#  (b'NOT', 147),
#  (b"they're", 147),
#  (b'giving', 147),
#  (b'college', 147),
#  (b'difficult', 147),
#  (b'fall', 146),
#  (b'laughed', 146),
#  (b'knows', 146),
#  (b'save', 146),
#  (b'incredible', 146),
#  (b'third', 146),
#  (b'potential', 146),
#  (b'leave', 146),
#  (b'song', 146),
#  (b'clearly', 146),
#  (b'Scott', 145),
#  (b'slasher', 145),
#  (b'talk', 145),
#  (b'laughing', 145),
#  (b'Every', 145),
#  (b'meets', 145),
#  (b'move', 145),
#  (b'fairly', 145),
#  (b'kill', 145),
#  (b'hero', 145),
#  (b'plain', 144),
#  (b'means', 144),
#  (b'p', 144),
#  (b'adventure', 144),
#  (b'suspense', 144),
#  (b'certain', 144),
#  (b'joke', 143),
#  (b'material', 142),
#  (b'rated', 142),
#  (b'showing', 142),
#  (b'Also', 142),
#  (b'mess', 142),
#  (b'needs', 142),
#  (b'World', 142),
#  (b'Ben', 142),
#  (b'gone', 141),
#  (b'books', 141),
#  (b'disappointment', 141),
#  (b'cop', 141),
#  (b'talented', 141),
#  (b'copy', 140),
#  (b'Bill', 140),
#  (b'Festival', 140),
#  (b'showed', 140),
#  (b'success', 139),
#  (b'interested', 138),
#  (b'fails', 138),
#  (b'shots', 138),
#  (b'stage', 138),
#  (b'describe', 138),
#  (b'Wow', 138),
#  (b'Okay', 137),
#  (b"she's", 137),
#  (b'wasted', 137),
#  (b'Jane', 137),
#  (b'particular', 137),
#  (b'spent', 137),
#  (b'whether', 137),
#  (b'bored', 136),
#  (b'wait', 136),
#  (b'clear', 136),
#  (b'rare', 136),
#  (b'Jim', 136),
#  (b'trash', 136),
#  (b'consider', 136),
#  ...]

# %%
vocab_size = 10000
truncated_vocabulary = [
 word for word, count in vocabulary.most_common()[:vocab_size]]
